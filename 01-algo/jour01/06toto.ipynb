# %%
tva = 10
prix = 30
total = tva * prix
print(total)
# Out:
# 300

# %% [markdown]
# # exemple de projet en Python

# %%
from pprint import pprint

liste = []
liste.append(1)
liste.append(2)
liste.append(3)

pprint (liste)
# Out:
# [1, 2, 3]
